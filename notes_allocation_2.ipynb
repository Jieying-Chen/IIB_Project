# %% [markdown]
# ## Note allocator ver2.0
# Key difference: consider about time & tempo

# %% [markdown]
# ### Constraints
# 1. num of pianists, 2 hands, 5 fingers
# 2. spatial apart (in each hand cannot exceed one octave)
# 3. within one octave > same intensity > last for same period
# 4. hand shape

# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from midiutil import MIDIFile
from pprint import pprint

from utils import *

import copy
import random

# %%
## Parameters
group_num = 21 * 2 #21 pianists, 2 hands each
max_note_per_group = 5 #5 fingers

#min_pitch_gap = not set
win_length = 25e-3
min_time_gap = 0.3
min_frame_gap = int(round(min_time_gap / win_length))

# %%
def scale_int(intensity_map):
    #scale the intensity map(0-1) to maximum=scale
    scale = 36
    l = np.array(intensity_map)
    l = l * scale / np.amax(l)
    return l.tolist()

def intensity2sign(intensity):
    #quantize the intensity -> to dynamic sign
    int_nm = round(intensity/16)*16
    if int_nm <=16:
        return 'ppp'
    elif int_nm ==32:
        return 'pp'
    elif int_nm ==48:
        return 'p'
    elif int_nm ==64:
        return 'mp'
    elif int_nm ==80:
        return 'mf'
    elif int_nm ==96:
        return 'f'
    elif int_nm ==112:
        return 'ff'
    elif int_nm >=127:
        return 'fff'
    
def int2vel(intensity):
    #intensity(in dB) to loudness, lowest loudness is (0dB) 16  
    base = 16
    return 10**(intensity/40) * base

def picknotes(cur_key, cur_freq, cur_int, notes, notes_list):
    j = 0
    while j < len(cur_key):
        if cur_key[j] == 0:
            j += 1
            continue
        pitch = cur_key[j]
        while pitch > 88:
            pitch -= 12
        
        start = j
        ori_int = cur_int[j]
        while cur_key[j] != 0 and j < len(cur_key)-1:
            j += 1
            ori_int = max(ori_int,cur_int[j])
        end = j - 1
        if end - start < 3: 
            end = start + 3 #all to 100ms
     
        intensity = get_intensity(cur_key[j-1],cur_freq,notes_list) * ori_int
        #intensity = ori_int
        intensity = int2vel(intensity)
        #intensity = get_intensity(cur_key[j-1],cur_freq,notes_list) * 100
        intensity_sign = intensity2sign(intensity)
        notes.append(Note(pitch, start, end, intensity, intensity_sign))
        j += 1
    return notes

def remove_repetitive(notes,note_num):
    #changed
    note_set = [0]*note_num
    i = 0
    while i < len(notes):
        note = notes[i]
        if note_set[note.pitch-1] == 0:
            note_set[note.pitch-1] = [note]
        else:
            delete = False
            for n in note_set[note.pitch-1]:
                if n.start == note.start and n.end == note.end:
                    n.intensity = max(n.intensity, note.intensity)
                    n.intensity_sign = intensity2sign(n.intensity)
                    del notes[i]
                    delete = True
                    i -= 1
                    break
            if not delete:
                note_set[note.pitch-1].append(note)
        i += 1
    return notes

# %%
key_time = 50e-3*0.5
Fs = 48000

## picked keys
#keys = scipy.io.loadmat('MATLAB_data/23Feb_jc_key_2octave.mat')['key']
keys = scipy.io.loadmat('MATLAB_data/jw_key_2octave.mat')['key']

##freq of notes on piano
notes_list = scipy.io.loadmat('notes_112.mat')['notes'] 

##freq of t-f components
freq_list = scipy.io.loadmat('freq_480_two_octave_down.mat')['f_cropped'] 

intensity_map = scipy.io.loadmat('MATLAB_data/jw_int_2octave.mat')['filtered_int_db']
intensity_map = scale_int(intensity_map)

notes_list = notes_list.reshape(np.size(notes_list))
freq_list = freq_list.reshape(np.size(freq_list))

note_num = 112

notes = []
for i in range(np.shape(keys)[0]):
    cur_key = keys[i]
    cur_int = intensity_map[i]
    cur_freq = freq_list[i]
    notes = picknotes(cur_key, cur_freq, cur_int, notes, notes_list)

notes = sorted(notes, key = lambda note: note.start)

new_notes = remove_repetitive(notes,note_num)
#pprint(new_notes)
separate_majors(new_notes)

# %%
pprint(new_notes)
print(len(new_notes))
plot_notes(new_notes)
# Out:
# [pitch = 70(time = 27-30), intensity sign = p, intensity = 40.374, major = 2, channel = -1,
#  pitch = 71(time = 27-30), intensity sign = ppp, intensity = 22.749, major = 1, channel = -1,
#  pitch = 74(time = 27-30), intensity sign = pp, intensity = 34.595, major = 2, channel = -1,
#  pitch = 75(time = 27-30), intensity sign = p, intensity = 40.682, major = 1, channel = -1,
#  pitch = 75(time = 27-32), intensity sign = p, intensity = 44.894, major = 2, channel = -1,
#  pitch = 75(time = 27-35), intensity sign = mp, intensity = 57.688, major = 1, channel = -1,
#  pitch = 75(time = 27-33), intensity sign = p, intensity = 49.698, major = 2, channel = -1,
#  pitch = 75(time = 27-31), intensity sign = pp, intensity = 36.995, major = 1, channel = -1,
#  pitch = 76(time = 27-31), intensity sign = pp, intensity = 35.168, major = 1, channel = -1,
#  pitch = 76(time = 27-33), intensity sign = p, intensity = 43.124, major = 1, channel = -1,
#  pitch = 76(time = 27-32), intensity sign = pp, intensity = 36.912, major = 1, channel = -1,
#  pitch = 76(time = 27-30), intensity sign = p, intensity = 40.732, major = 1, channel = -1,
#  pitch = 77(time = 27-30), intensity sign = pp, intensity = 38.249, major = 2, channel = -1,
#  pitch = 77(time = 27-32), intensity sign = pp, intensity = 39.323, major = 2, channel = -1,
#  pitch = 79(time = 27-33), intensity sign = p, intensity = 42.792, major = 2, channel = -1,
#  pitch = 80(time = 27-30), intensity sign = pp, intensity = 32.076, major = 1, channel = -1,
#  pitch = 81(time = 27-30), intensity sign = pp, intensity = 35.338, major = 2, channel = -1,
#  pitch = 64(time = 28-31), intensity sign = pp, intensity = 30.385, major = 1, channel = -1,
#  pitch = 68(time = 28-31), intensity sign = pp, intensity = 39.414, major = 1, channel = -1,
#  pitch = 68(time = 28-34), intensity sign = pp, intensity = 36.159, major = 1, channel = -1,
#  pitch = 70(time = 28-35), intensity sign = mf, intensity = 72.945, major = 2, channel = -1,
#  pitch = 70(time = 28-32), intensity sign = pp, intensity = 36.942, major = 2, channel = -1,
#  pitch = 70(time = 28-31), intensity sign = pp, intensity = 38.966, major = 2, channel = -1,
#  pitch = 74(time = 28-31), intensity sign = pp, intensity = 38.044, major = 2, channel = -1,
#  pitch = 74(time = 28-35), intensity sign = p, intensity = 53.043, major = 2, channel = -1,
#  pitch = 75(time = 28-35), intensity sign = p, intensity = 50.453, major = 1, channel = -1,
#  pitch = 75(time = 28-32), intensity sign = mp, intensity = 57.603, major = 2, channel = -1,
#  pitch = 75(time = 28-31), intensity sign = p, intensity = 50.700, major = 1, channel = -1,
#  pitch = 75(time = 28-34), intensity sign = p, intensity = 48.991, major = 2, channel = -1,
#  pitch = 75(time = 28-33), intensity sign = p, intensity = 53.701, major = 1, channel = -1,
#  pitch = 76(time = 28-33), intensity sign = mp, intensity = 57.111, major = 1, channel = -1,
#  pitch = 76(time = 28-31), intensity sign = mp, intensity = 62.184, major = 1, channel = -1,
#  pitch = 76(time = 28-32), intensity sign = mp, intensity = 62.097, major = 1, channel = -1,
#  pitch = 76(time = 28-34), intensity sign = p, intensity = 43.454, major = 1, channel = -1,
#  pitch = 76(time = 28-35), intensity sign = p, intensity = 41.202, major = 1, channel = -1,
#  pitch = 77(time = 28-31), intensity sign = p, intensity = 42.376, major = 2, channel = -1,
#  pitch = 77(time = 28-32), intensity sign = p, intensity = 45.849, major = 2, channel = -1,
#  pitch = 77(time = 28-33), intensity sign = p, intensity = 46.272, major = 2, channel = -1,
#  pitch = 78(time = 28-31), intensity sign = p, intensity = 49.057, major = 1, channel = -1,
#  pitch = 78(time = 28-33), intensity sign = p, intensity = 45.288, major = 1, channel = -1,
#  pitch = 78(time = 28-32), intensity sign = p, intensity = 48.263, major = 1, channel = -1,
#  pitch = 79(time = 28-31), intensity sign = pp, intensity = 39.573, major = 2, channel = -1,
#  pitch = 79(time = 28-32), intensity sign = pp, intensity = 39.774, major = 2, channel = -1,
#  pitch = 79(time = 28-33), intensity sign = p, intensity = 43.211, major = 2, channel = -1,
#  pitch = 80(time = 28-33), intensity sign = pp, intensity = 31.291, major = 1, channel = -1,
#  pitch = 80(time = 28-32), intensity sign = pp, intensity = 31.616, major = 1, channel = -1,
#  pitch = 80(time = 28-31), intensity sign = pp, intensity = 32.900, major = 1, channel = -1,
#  pitch = 81(time = 28-31), intensity sign = pp, intensity = 33.145, major = 2, channel = -1,
#  pitch = 82(time = 28-31), intensity sign = pp, intensity = 31.180, major = 2, channel = -1,
#  pitch = 82(time = 28-32), intensity sign = pp, intensity = 29.603, major = 2, channel = -1,
#  pitch = 83(time = 28-31), intensity sign = pp, intensity = 33.194, major = 1, channel = -1,
#  pitch = 64(time = 29-32), intensity sign = pp, intensity = 27.156, major = 1, channel = -1,
#  pitch = 65(time = 29-32), intensity sign = ppp, intensity = 23.340, major = 2, channel = -1,
#  pitch = 67(time = 29-32), intensity sign = pp, intensity = 30.331, major = 2, channel = -1,
#  pitch = 68(time = 29-32), intensity sign = pp, intensity = 28.785, major = 1, channel = -1,
#  pitch = 69(time = 29-32), intensity sign = p, intensity = 40.097, major = 1, channel = -1,
#  pitch = 69(time = 29-33), intensity sign = p, intensity = 40.905, major = 2, channel = -1,
#  pitch = 69(time = 29-35), intensity sign = p, intensity = 55.719, major = 1, channel = -1,
#  pitch = 70(time = 29-32), intensity sign = p, intensity = 41.191, major = 2, channel = -1,
#  pitch = 70(time = 29-34), intensity sign = p, intensity = 47.350, major = 2, channel = -1,
#  pitch = 71(time = 29-32), intensity sign = pp, intensity = 35.909, major = 1, channel = -1,
#  pitch = 75(time = 29-35), intensity sign = p, intensity = 44.261, major = 2, channel = -1,
#  pitch = 75(time = 29-32), intensity sign = p, intensity = 41.972, major = 1, channel = -1,
#  pitch = 75(time = 29-33), intensity sign = p, intensity = 50.344, major = 2, channel = -1,
#  pitch = 77(time = 29-32), intensity sign = p, intensity = 45.247, major = 2, channel = -1,
#  pitch = 78(time = 29-33), intensity sign = pp, intensity = 33.386, major = 1, channel = -1,
#  pitch = 79(time = 29-32), intensity sign = pp, intensity = 29.595, major = 2, channel = -1,
#  pitch = 79(time = 29-33), intensity sign = pp, intensity = 30.648, major = 2, channel = -1,
#  pitch = 80(time = 29-33), intensity sign = pp, intensity = 30.620, major = 1, channel = -1,
#  pitch = 80(time = 29-32), intensity sign = pp, intensity = 31.780, major = 1, channel = -1,
#  pitch = 81(time = 29-32), intensity sign = pp, intensity = 32.151, major = 1, channel = -1,
#  pitch = 82(time = 29-32), intensity sign = p, intensity = 40.087, major = 2, channel = -1,
#  pitch = 82(time = 29-33), intensity sign = p, intensity = 40.021, major = 2, channel = -1,
#  pitch = 83(time = 29-32), intensity sign = pp, intensity = 37.507, major = 1, channel = -1,
#  pitch = 84(time = 29-32), intensity sign = pp, intensity = 27.398, major = 2, channel = -1,
#  pitch = 85(time = 29-32), intensity sign = pp, intensity = 28.692, major = 1, channel = -1,
#  pitch = 68(time = 30-34), intensity sign = p, intensity = 47.744, major = 1, channel = -1,
#  pitch = 68(time = 30-39), intensity sign = mf, intensity = 85.775, major = 1, channel = -1,
#  pitch = 68(time = 30-40), intensity sign = ff, intensity = 111.036, major = 1, channel = -1,
#  pitch = 68(time = 30-41), intensity sign = fff, intensity = 121.147, major = 1, channel = -1,
#  pitch = 68(time = 30-33), intensity sign = p, intensity = 47.353, major = 1, channel = -1,
#  pitch = 68(time = 30-42), intensity sign = f, intensity = 89.726, major = 1, channel = -1,
#  pitch = 70(time = 30-33), intensity sign = pp, intensity = 29.632, major = 2, channel = -1,
#  pitch = 71(time = 30-33), intensity sign = pp, intensity = 27.223, major = 1, channel = -1,
#  pitch = 74(time = 30-33), intensity sign = p, intensity = 40.635, major = 2, channel = -1,
#  pitch = 74(time = 30-37), intensity sign = mf, intensity = 79.131, major = 2, channel = -1,
#  pitch = 74(time = 30-35), intensity sign = mp, intensity = 60.649, major = 2, channel = -1,
#  pitch = 77(time = 30-33), intensity sign = pp, intensity = 37.132, major = 2, channel = -1,
#  pitch = 78(time = 30-33), intensity sign = p, intensity = 45.276, major = 1, channel = -1,
#  pitch = 79(time = 30-33), intensity sign = pp, intensity = 28.980, major = 2, channel = -1,
#  pitch = 81(time = 30-33), intensity sign = pp, intensity = 39.232, major = 2, channel = -1,
#  pitch = 82(time = 30-33), intensity sign = pp, intensity = 39.103, major = 2, channel = -1,
#  pitch = 83(time = 30-33), intensity sign = pp, intensity = 34.642, major = 1, channel = -1,
#  pitch = 85(time = 30-33), intensity sign = pp, intensity = 29.633, major = 1, channel = -1,
#  pitch = 68(time = 31-34), intensity sign = pp, intensity = 31.736, major = 1, channel = -1,
#  pitch = 69(time = 31-34), intensity sign = pp, intensity = 27.523, major = 1, channel = -1,
#  pitch = 70(time = 31-35), intensity sign = mp, intensity = 67.349, major = 2, channel = -1,
#  pitch = 70(time = 31-34), intensity sign = p, intensity = 52.380, major = 2, channel = -1,
#  pitch = 71(time = 31-34), intensity sign = pp, intensity = 31.674, major = 1, channel = -1,
#  pitch = 75(time = 31-35), intensity sign = mp, intensity = 57.187, major = 2, channel = -1,
#  pitch = 75(time = 31-34), intensity sign = mp, intensity = 56.613, major = 1, channel = -1,
#  pitch = 77(time = 31-34), intensity sign = pp, intensity = 30.163, major = 2, channel = -1,
#  pitch = 78(time = 31-34), intensity sign = p, intensity = 40.187, major = 1, channel = -1,
#  pitch = 80(time = 31-34), intensity sign = pp, intensity = 31.730, major = 1, channel = -1,
#  pitch = 81(time = 31-34), intensity sign = pp, intensity = 36.699, major = 2, channel = -1,
#  pitch = 82(time = 31-34), intensity sign = pp, intensity = 31.062, major = 2, channel = -1,
#  pitch = 83(time = 31-34), intensity sign = pp, intensity = 37.429, major = 1, channel = -1,
#  pitch = 69(time = 32-35), intensity sign = p, intensity = 41.232, major = 1, channel = -1,
#  pitch = 69(time = 32-36), intensity sign = f, intensity = 90.838, major = 2, channel = -1,
#  pitch = 70(time = 32-35), intensity sign = mf, intensity = 73.432, major = 2, channel = -1,
#  pitch = 72(time = 32-35), intensity sign = mp, intensity = 59.461, major = 2, channel = -1,
#  pitch = 73(time = 32-35), intensity sign = p, intensity = 43.419, major = 1, channel = -1,
#  pitch = 74(time = 32-35), intensity sign = p, intensity = 47.253, major = 2, channel = -1,
#  pitch = 74(time = 32-37), intensity sign = f, intensity = 93.747, major = 2, channel = -1,
#  pitch = 74(time = 32-36), intensity sign = mp, intensity = 56.140, major = 2, channel = -1,
#  pitch = 76(time = 32-35), intensity sign = p, intensity = 47.594, major = 1, channel = -1,
#  pitch = 77(time = 32-35), intensity sign = pp, intensity = 39.288, major = 2, channel = -1,
#  pitch = 78(time = 32-35), intensity sign = pp, intensity = 36.657, major = 1, channel = -1,
#  pitch = 79(time = 32-35), intensity sign = pp, intensity = 39.556, major = 2, channel = -1,
#  pitch = 80(time = 32-35), intensity sign = pp, intensity = 35.413, major = 1, channel = -1,
#  pitch = 81(time = 32-35), intensity sign = pp, intensity = 31.418, major = 1, channel = -1,
#  pitch = 82(time = 32-35), intensity sign = pp, intensity = 28.126, major = 2, channel = -1,
#  pitch = 84(time = 32-35), intensity sign = pp, intensity = 27.081, major = 2, channel = -1,
#  pitch = 36(time = 33-36), intensity sign = pp, intensity = 31.569, major = 2, channel = -1,
#  pitch = 36(time = 33-42), intensity sign = pp, intensity = 35.908, major = 2, channel = -1,
#  pitch = 37(time = 33-42), intensity sign = mp, intensity = 68.443, major = 1, channel = -1,
#  pitch = 38(time = 33-42), intensity sign = p, intensity = 49.389, major = 2, channel = -1,
#  pitch = 38(time = 33-43), intensity sign = mf, intensity = 74.861, major = 2, channel = -1,
#  pitch = 39(time = 33-43), intensity sign = p, intensity = 43.028, major = 2, channel = -1,
#  pitch = 39(time = 33-44), intensity sign = mf, intensity = 82.264, major = 1, channel = -1,
#  pitch = 39(time = 33-37), intensity sign = mf, intensity = 72.107, major = 2, channel = -1,
#  pitch = 39(time = 33-36), intensity sign = p, intensity = 54.210, major = 1, channel = -1,
#  pitch = 40(time = 33-36), intensity sign = mp, intensity = 63.611, major = 1, channel = -1,
#  pitch = 41(time = 33-36), intensity sign = pp, intensity = 38.573, major = 2, channel = -1,
#  pitch = 42(time = 33-36), intensity sign = pp, intensity = 25.757, major = 1, channel = -1,
#  pitch = 64(time = 33-36), intensity sign = pp, intensity = 28.331, major = 1, channel = -1,
#  pitch = 65(time = 33-36), intensity sign = pp, intensity = 30.628, major = 2, channel = -1,
#  pitch = 66(time = 33-36), intensity sign = pp, intensity = 34.829, major = 1, channel = -1,
#  pitch = 67(time = 33-36), intensity sign = mp, intensity = 56.250, major = 2, channel = -1,
#  pitch = 68(time = 33-36), intensity sign = pp, intensity = 32.132, major = 1, channel = -1,
#  pitch = 69(time = 33-36), intensity sign = f, intensity = 89.754, major = 2, channel = -1,
#  pitch = 69(time = 33-42), intensity sign = mf, intensity = 73.601, major = 1, channel = -1,
#  pitch = 69(time = 33-41), intensity sign = mf, intensity = 76.831, major = 2, channel = -1,
#  pitch = 69(time = 33-38), intensity sign = mf, intensity = 81.662, major = 1, channel = -1,
#  pitch = 71(time = 33-36), intensity sign = p, intensity = 54.928, major = 1, channel = -1,
#  pitch = 71(time = 33-37), intensity sign = p, intensity = 50.593, major = 1, channel = -1,
#  pitch = 72(time = 33-36), intensity sign = mp, intensity = 63.572, major = 2, channel = -1,
#  pitch = 73(time = 33-36), intensity sign = p, intensity = 45.608, major = 1, channel = -1,
#  pitch = 73(time = 33-39), intensity sign = mp, intensity = 62.945, major = 1, channel = -1,
#  pitch = 74(time = 33-37), intensity sign = f, intensity = 91.848, major = 2, channel = -1,
#  pitch = 75(time = 33-36), intensity sign = pp, intensity = 25.454, major = 2, channel = -1,
#  pitch = 76(time = 33-36), intensity sign = pp, intensity = 24.644, major = 1, channel = -1,
#  pitch = 78(time = 33-36), intensity sign = pp, intensity = 37.640, major = 1, channel = -1,
#  pitch = 79(time = 33-36), intensity sign = pp, intensity = 28.786, major = 2, channel = -1,
#  pitch = 81(time = 33-36), intensity sign = pp, intensity = 30.213, major = 1, channel = -1,
#  pitch = 82(time = 33-36), intensity sign = pp, intensity = 29.962, major = 2, channel = -1,
#  pitch = 50(time = 34-37), intensity sign = pp, intensity = 29.680, major = 2, channel = -1,
#  pitch = 51(time = 34-37), intensity sign = pp, intensity = 36.518, major = 2, channel = -1,
#  pitch = 52(time = 34-37), intensity sign = ppp, intensity = 23.269, major = 1, channel = -1,
#  pitch = 57(time = 34-37), intensity sign = pp, intensity = 26.490, major = 1, channel = -1,
#  pitch = 58(time = 34-37), intensity sign = p, intensity = 45.344, major = 2, channel = -1,
#  pitch = 59(time = 34-37), intensity sign = pp, intensity = 26.953, major = 1, channel = -1,
#  pitch = 62(time = 34-37), intensity sign = pp, intensity = 29.212, major = 2, channel = -1,
#  pitch = 63(time = 34-37), intensity sign = p, intensity = 54.168, major = 2, channel = -1,
#  pitch = 64(time = 34-37), intensity sign = pp, intensity = 30.116, major = 1, channel = -1,
#  pitch = 66(time = 34-37), intensity sign = p, intensity = 48.096, major = 1, channel = -1,
#  pitch = 67(time = 34-37), intensity sign = mp, intensity = 61.220, major = 2, channel = -1,
#  pitch = 68(time = 34-37), intensity sign = pp, intensity = 27.105, major = 1, channel = -1,
#  pitch = 68(time = 34-42), intensity sign = mp, intensity = 71.560, major = 1, channel = -1,
#  pitch = 70(time = 34-37), intensity sign = mp, intensity = 70.314, major = 2, channel = -1,
#  pitch = 71(time = 34-37), intensity sign = pp, intensity = 24.216, major = 1, channel = -1,
#  pitch = 72(time = 34-37), intensity sign = mp, intensity = 63.116, major = 2, channel = -1,
#  pitch = 73(time = 34-37), intensity sign = p, intensity = 41.611, major = 1, channel = -1,
#  pitch = 74(time = 34-40), intensity sign = mf, intensity = 77.157, major = 2, channel = -1,
#  pitch = 75(time = 34-37), intensity sign = p, intensity = 46.406, major = 1, channel = -1,
#  pitch = 77(time = 34-37), intensity sign = pp, intensity = 25.334, major = 2, channel = -1,
#  pitch = 85(time = 34-37), intensity sign = pp, intensity = 31.142, major = 1, channel = -1,
#  pitch = 86(time = 34-37), intensity sign = pp, intensity = 30.951, major = 2, channel = -1,
#  pitch = 36(time = 35-40), intensity sign = p, intensity = 52.106, major = 2, channel = -1,
#  pitch = 36(time = 35-41), intensity sign = p, intensity = 55.703, major = 2, channel = -1,
#  pitch = 49(time = 35-41), intensity sign = pp, intensity = 34.371, major = 1, channel = -1,
#  pitch = 49(time = 35-38), intensity sign = pp, intensity = 32.173, major = 1, channel = -1,
#  pitch = 50(time = 35-38), intensity sign = pp, intensity = 37.954, major = 2, channel = -1,
#  pitch = 56(time = 35-38), intensity sign = pp, intensity = 26.840, major = 1, channel = -1,
#  pitch = 57(time = 35-38), intensity sign = pp, intensity = 34.826, major = 2, channel = -1,
#  pitch = 61(time = 35-38), intensity sign = pp, intensity = 33.769, major = 1, channel = -1,
#  pitch = 62(time = 35-38), intensity sign = p, intensity = 46.763, major = 2, channel = -1,
#  pitch = 65(time = 35-42), intensity sign = mp, intensity = 60.424, major = 2, channel = -1,
#  pitch = 65(time = 35-40), intensity sign = p, intensity = 50.025, major = 2, channel = -1,
#  pitch = 65(time = 35-38), intensity sign = pp, intensity = 35.332, major = 2, channel = -1,
#  pitch = 66(time = 35-38), intensity sign = p, intensity = 44.339, major = 1, channel = -1,
#  pitch = 68(time = 35-42), intensity sign = p, intensity = 52.425, major = 1, channel = -1,
#  pitch = 69(time = 35-42), intensity sign = mp, intensity = 67.582, major = 1, channel = -1,
#  pitch = 69(time = 35-38), intensity sign = f, intensity = 95.929, major = 2, channel = -1,
#  pitch = 71(time = 35-42), intensity sign = ff, intensity = 112.933, major = 1, channel = -1,
#  pitch = 71(time = 35-40), intensity sign = ff, intensity = 116.060, major = 1, channel = -1,
#  pitch = 71(time = 35-38), intensity sign = mp, intensity = 66.893, major = 1, channel = -1,
#  pitch = 72(time = 35-38), intensity sign = mp, intensity = 62.489, major = 2, channel = -1,
#  pitch = 73(time = 35-40), intensity sign = mf, intensity = 72.228, major = 1, channel = -1,
#  pitch = 74(time = 35-38), intensity sign = f, intensity = 89.793, major = 2, channel = -1,
#  pitch = 74(time = 35-40), intensity sign = mf, intensity = 80.894, major = 2, channel = -1,
#  pitch = 76(time = 35-38), intensity sign = pp, intensity = 36.033, major = 1, channel = -1,
#  pitch = 77(time = 35-38), intensity sign = ppp, intensity = 23.639, major = 2, channel = -1,
#  pitch = 78(time = 35-38), intensity sign = pp, intensity = 30.236, major = 1, channel = -1,
#  pitch = 85(time = 35-38), intensity sign = pp, intensity = 26.432, major = 1, channel = -1,
#  pitch = 35(time = 36-39), intensity sign = pp, intensity = 34.969, major = 1, channel = -1,
#  pitch = 49(time = 36-39), intensity sign = pp, intensity = 37.642, major = 1, channel = -1,
#  pitch = 49(time = 36-41), intensity sign = pp, intensity = 36.639, major = 1, channel = -1,
#  pitch = 56(time = 36-40), intensity sign = pp, intensity = 39.023, major = 1, channel = -1,
#  pitch = 56(time = 36-41), intensity sign = pp, intensity = 32.025, major = 1, channel = -1,
#  pitch = 61(time = 36-40), intensity sign = p, intensity = 49.192, major = 1, channel = -1,
#  pitch = 61(time = 36-39), intensity sign = pp, intensity = 34.266, major = 1, channel = -1,
#  pitch = 65(time = 36-39), intensity sign = f, intensity = 95.902, major = 2, channel = -1,
#  pitch = 65(time = 36-41), intensity sign = f, intensity = 98.338, major = 2, channel = -1,
#  pitch = 65(time = 36-42), intensity sign = mf, intensity = 87.548, major = 2, channel = -1,
#  pitch = 68(time = 36-39), intensity sign = mf, intensity = 76.537, major = 1, channel = -1,
#  pitch = 68(time = 36-41), intensity sign = fff, intensity = 123.073, major = 1, channel = -1,
#  pitch = 68(time = 36-42), intensity sign = f, intensity = 94.229, major = 1, channel = -1,
#  pitch = 71(time = 36-39), intensity sign = p, intensity = 48.426, major = 1, channel = -1,
#  pitch = 71(time = 36-40), intensity sign = mp, intensity = 64.852, major = 1, channel = -1,
#  pitch = 71(time = 36-41), intensity sign = mf, intensity = 83.748, major = 1, channel = -1,
#  pitch = 71(time = 36-42), intensity sign = f, intensity = 98.775, major = 1, channel = -1,
#  pitch = 73(time = 36-39), intensity sign = ff, intensity = 105.521, major = 1, channel = -1,
#  pitch = 73(time = 36-40), intensity sign = mf, intensity = 77.679, major = 1, channel = -1,
#  pitch = 75(time = 36-39), intensity sign = mp, intensity = 65.953, major = 1, channel = -1,
#  pitch = 76(time = 36-39), intensity sign = pp, intensity = 35.258, major = 1, channel = -1,
#  pitch = 77(time = 36-39), intensity sign = p, intensity = 41.617, major = 2, channel = -1,
#  pitch = 79(time = 36-39), intensity sign = pp, intensity = 34.538, major = 2, channel = -1,
#  pitch = 35(time = 37-40), intensity sign = pp, intensity = 35.114, major = 1, channel = -1,
#  pitch = 48(time = 37-40), intensity sign = pp, intensity = 24.631, major = 2, channel = -1,
#  pitch = 49(time = 37-40), intensity sign = pp, intensity = 28.738, major = 1, channel = -1,
#  pitch = 56(time = 37-40), intensity sign = pp, intensity = 38.672, major = 1, channel = -1,
#  pitch = 61(time = 37-40), intensity sign = p, intensity = 46.039, major = 1, channel = -1,
#  pitch = 64(time = 37-40), intensity sign = pp, intensity = 34.204, major = 1, channel = -1,
#  pitch = 65(time = 37-40), intensity sign = p, intensity = 52.344, major = 2, channel = -1,
#  pitch = 68(time = 37-40), intensity sign = pp, intensity = 39.930, major = 1, channel = -1,
#  pitch = 70(time = 37-40), intensity sign = p, intensity = 42.004, major = 2, channel = -1,
#  pitch = 73(time = 37-40), intensity sign = p, intensity = 53.308, major = 1, channel = -1,
#  pitch = 74(time = 37-40), intensity sign = pp, intensity = 29.673, major = 2, channel = -1,
#  pitch = 75(time = 37-40), intensity sign = mp, intensity = 61.674, major = 2, channel = -1,
#  pitch = 77(time = 37-40), intensity sign = p, intensity = 41.929, major = 2, channel = -1,
#  pitch = 78(time = 37-40), intensity sign = pp, intensity = 26.534, major = 1, channel = -1,
#  pitch = 79(time = 37-40), intensity sign = pp, intensity = 32.082, major = 2, channel = -1,
#  pitch = 49(time = 38-41), intensity sign = pp, intensity = 31.309, major = 1, channel = -1,
#  pitch = 50(time = 38-41), intensity sign = p, intensity = 48.404, major = 2, channel = -1,
#  pitch = 56(time = 38-41), intensity sign = pp, intensity = 30.006, major = 1, channel = -1,
#  pitch = 57(time = 38-41), intensity sign = pp, intensity = 32.867, major = 1, channel = -1,
#  pitch = 61(time = 38-41), intensity sign = pp, intensity = 32.117, major = 1, channel = -1,
#  pitch = 66(time = 38-41), intensity sign = pp, intensity = 28.431, major = 1, channel = -1,
#  pitch = 74(time = 38-41), intensity sign = pp, intensity = 31.138, major = 2, channel = -1,
#  pitch = 81(time = 38-41), intensity sign = pp, intensity = 26.863, major = 2, channel = -1,
#  pitch = 39(time = 39-44), intensity sign = mp, intensity = 63.731, major = 1, channel = -1,
#  pitch = 57(time = 39-42), intensity sign = p, intensity = 42.585, major = 2, channel = -1,
#  pitch = 61(time = 39-42), intensity sign = p, intensity = 49.191, major = 1, channel = -1,
#  pitch = 62(time = 39-42), intensity sign = p, intensity = 45.945, major = 2, channel = -1,
#  pitch = 65(time = 39-42), intensity sign = pp, intensity = 32.268, major = 2, channel = -1,
#  pitch = 66(time = 39-42), intensity sign = pp, intensity = 35.377, major = 1, channel = -1,
#  pitch = 69(time = 39-42), intensity sign = mp, intensity = 70.835, major = 1, channel = -1,
#  pitch = 71(time = 39-42), intensity sign = p, intensity = 45.333, major = 1, channel = -1,
#  pitch = 72(time = 39-42), intensity sign = pp, intensity = 28.902, major = 2, channel = -1,
#  pitch = 74(time = 39-42), intensity sign = pp, intensity = 30.208, major = 2, channel = -1,
#  pitch = 75(time = 39-42), intensity sign = pp, intensity = 30.064, major = 2, channel = -1,
#  pitch = 76(time = 39-42), intensity sign = ppp, intensity = 23.678, major = 1, channel = -1,
#  pitch = 77(time = 39-42), intensity sign = pp, intensity = 31.865, major = 2, channel = -1,
#  pitch = 40(time = 40-44), intensity sign = p, intensity = 51.919, major = 1, channel = -1,
#  pitch = 50(time = 40-43), intensity sign = p, intensity = 50.601, major = 2, channel = -1,
#  pitch = 57(time = 40-43), intensity sign = p, intensity = 51.206, major = 1, channel = -1,
#  pitch = 62(time = 40-43), intensity sign = mf, intensity = 81.236, major = 2, channel = -1,
#  pitch = 66(time = 40-43), intensity sign = p, intensity = 46.542, major = 1, channel = -1,
#  pitch = 69(time = 40-43), intensity sign = mf, intensity = 77.268, major = 2, channel = -1,
#  pitch = 70(time = 40-43), intensity sign = ppp, intensity = 22.880, major = 2, channel = -1,
#  pitch = 71(time = 40-43), intensity sign = p, intensity = 40.326, major = 1, channel = -1,
#  pitch = 72(time = 40-43), intensity sign = pp, intensity = 27.805, major = 2, channel = -1,
#  pitch = 74(time = 40-43), intensity sign = pp, intensity = 32.611, major = 2, channel = -1,
#  pitch = 40(time = 41-44), intensity sign = mp, intensity = 68.477, major = 1, channel = -1,
#  pitch = 51(time = 41-44), intensity sign = p, intensity = 45.892, major = 1, channel = -1,
#  pitch = 57(time = 41-44), intensity sign = pp, intensity = 38.122, major = 2, channel = -1,
#  pitch = 58(time = 41-44), intensity sign = p, intensity = 54.290, major = 2, channel = -1,
#  pitch = 62(time = 41-44), intensity sign = pp, intensity = 38.171, major = 2, channel = -1,
#  pitch = 63(time = 41-44), intensity sign = p, intensity = 53.982, major = 1, channel = -1,
#  pitch = 65(time = 41-44), intensity sign = pp, intensity = 34.851, major = 2, channel = -1,
#  pitch = 66(time = 41-44), intensity sign = p, intensity = 50.334, major = 1, channel = -1,
#  pitch = 69(time = 41-44), intensity sign = p, intensity = 46.253, major = 2, channel = -1,
#  pitch = 72(time = 41-44), intensity sign = pp, intensity = 31.220, major = 2, channel = -1,
#  pitch = 40(time = 42-45), intensity sign = mp, intensity = 62.387, major = 1, channel = -1,
#  pitch = 40(time = 42-46), intensity sign = p, intensity = 51.056, major = 1, channel = -1,
#  pitch = 41(time = 42-46), intensity sign = p, intensity = 48.180, major = 2, channel = -1,
#  pitch = 51(time = 42-45), intensity sign = p, intensity = 45.123, major = 1, channel = -1,
#  pitch = 52(time = 42-45), intensity sign = pp, intensity = 31.321, major = 1, channel = -1,
#  pitch = 58(time = 42-45), intensity sign = mp, intensity = 56.423, major = 2, channel = -1,
#  pitch = 63(time = 42-45), intensity sign = mp, intensity = 56.597, major = 2, channel = -1,
#  pitch = 65(time = 42-45), intensity sign = pp, intensity = 27.175, major = 2, channel = -1,
#  pitch = 66(time = 42-45), intensity sign = pp, intensity = 27.863, major = 1, channel = -1,
#  pitch = 67(time = 42-45), intensity sign = pp, intensity = 28.260, major = 2, channel = -1,
#  pitch = 70(time = 42-45), intensity sign = pp, intensity = 27.469, major = 2, channel = -1,
#  pitch = 41(time = 43-46), intensity sign = mp, intensity = 61.156, major = 2, channel = -1,
#  pitch = 41(time = 43-47), intensity sign = mp, intensity = 69.793, major = 2, channel = -1,
#  pitch = 42(time = 43-47), intensity sign = p, intensity = 52.996, major = 1, channel = -1,
#  pitch = 52(time = 43-46), intensity sign = p, intensity = 43.153, major = 1, channel = -1,
#  pitch = 53(time = 43-46), intensity sign = pp, intensity = 32.927, major = 2, channel = -1,
#  pitch = 58(time = 43-46), intensity sign = pp, intensity = 37.376, major = 2, channel = -1,
#  pitch = 59(time = 43-46), intensity sign = mp, intensity = 56.757, major = 1, channel = -1,
#  pitch = 60(time = 43-46), intensity sign = pp, intensity = 33.280, major = 2, channel = -1,
#  pitch = 62(time = 43-46), intensity sign = pp, intensity = 32.156, major = 2, channel = -1,
#  pitch = 63(time = 43-46), intensity sign = pp, intensity = 34.784, major = 1, channel = -1,
#  pitch = 64(time = 43-46), intensity sign = pp, intensity = 38.142, major = 1, channel = -1,
#  pitch = 42(time = 44-47), intensity sign = mf, intensity = 73.361, major = 1, channel = -1,
#  pitch = 43(time = 44-47), intensity sign = p, intensity = 53.095, major = 2, channel = -1,
#  pitch = 53(time = 44-47), intensity sign = p, intensity = 47.290, major = 2, channel = -1,
#  pitch = 54(time = 44-47), intensity sign = pp, intensity = 27.060, major = 1, channel = -1,
#  pitch = 60(time = 44-47), intensity sign = pp, intensity = 36.324, major = 2, channel = -1,
#  pitch = 64(time = 44-47), intensity sign = pp, intensity = 29.894, major = 1, channel = -1,
#  pitch = 65(time = 44-47), intensity sign = pp, intensity = 30.639, major = 2, channel = -1,
#  pitch = 43(time = 45-48), intensity sign = p, intensity = 55.952, major = 2, channel = -1,
#  pitch = 44(time = 45-48), intensity sign = pp, intensity = 28.098, major = 1, channel = -1,
#  pitch = 54(time = 45-48), intensity sign = p, intensity = 46.163, major = 1, channel = -1,
#  pitch = 55(time = 45-48), intensity sign = pp, intensity = 36.020, major = 2, channel = -1,
#  pitch = 60(time = 45-48), intensity sign = pp, intensity = 36.551, major = 2, channel = -1,
#  pitch = 55(time = 46-49), intensity sign = pp, intensity = 37.795, major = 2, channel = -1,
#  pitch = 61(time = 46-49), intensity sign = pp, intensity = 26.846, major = 1, channel = -1,
#  pitch = 62(time = 46-49), intensity sign = pp, intensity = 27.924, major = 2, channel = -1,
#  pitch = 53(time = 47-50), intensity sign = pp, intensity = 24.406, major = 2, channel = -1,
#  pitch = 54(time = 47-50), intensity sign = pp, intensity = 30.304, major = 1, channel = -1,
#  pitch = 33(time = 74-92), intensity sign = p, intensity = 52.827, major = 2, channel = -1,
#  pitch = 34(time = 74-92), intensity sign = mf, intensity = 75.324, major = 2, channel = -1,
#  pitch = 34(time = 74-86), intensity sign = mp, intensity = 69.483, major = 2, channel = -1,
#  pitch = 35(time = 74-86), intensity sign = mp, intensity = 58.380, major = 1, channel = -1,
#  pitch = 35(time = 74-85), intensity sign = f, intensity = 90.686, major = 1, channel = -1,
#  pitch = 35(time = 74-83), intensity sign = p, intensity = 46.068, major = 1, channel = -1,
#  pitch = 36(time = 74-83), intensity sign = f, intensity = 89.004, major = 2, channel = -1,
#  pitch = 36(time = 74-82), intensity sign = p, intensity = 42.777, major = 2, channel = -1,
#  pitch = 37(time = 74-81), intensity sign = mp, intensity = 58.567, major = 1, channel = -1,
#  pitch = 37(time = 74-80), intensity sign = mp, intensity = 70.406, major = 1, channel = -1,
#  pitch = 37(time = 74-79), intensity sign = pp, intensity = 36.216, major = 1, channel = -1,
#  pitch = 38(time = 74-78), intensity sign = pp, intensity = 35.906, major = 2, channel = -1,
#  pitch = 38(time = 74-77), intensity sign = pp, intensity = 38.905, major = 2, channel = -1,
#  pitch = 39(time = 74-77), intensity sign = pp, intensity = 29.297, major = 1, channel = -1,
#  pitch = 67(time = 74-78), intensity sign = p, intensity = 51.774, major = 2, channel = -1,
#  pitch = 67(time = 74-77), intensity sign = p, intensity = 53.687, major = 2, channel = -1,
#  pitch = 68(time = 74-77), intensity sign = pp, intensity = 28.559, major = 1, channel = -1,
#  pitch = 33(time = 75-78), intensity sign = pp, intensity = 28.196, major = 2, channel = -1,
#  pitch = 33(time = 75-92), intensity sign = mp, intensity = 65.481, major = 1, channel = -1,
#  pitch = 47(time = 75-81), intensity sign = pp, intensity = 39.689, major = 1, channel = -1,
#  pitch = 47(time = 75-80), intensity sign = pp, intensity = 35.513, major = 1, channel = -1,
#  pitch = 48(time = 75-80), intensity sign = pp, intensity = 34.108, major = 2, channel = -1,
#  pitch = 48(time = 75-79), intensity sign = pp, intensity = 36.468, major = 2, channel = -1,
#  pitch = 48(time = 75-78), intensity sign = pp, intensity = 37.387, major = 2, channel = -1,
#  pitch = 63(time = 75-78), intensity sign = pp, intensity = 38.779, major = 2, channel = -1,
#  pitch = 64(time = 75-78), intensity sign = pp, intensity = 36.386, major = 1, channel = -1,
#  pitch = 66(time = 75-79), intensity sign = p, intensity = 50.452, major = 1, channel = -1,
#  pitch = 67(time = 75-79), intensity sign = p, intensity = 43.777, major = 2, channel = -1,
#  pitch = 67(time = 75-78), intensity sign = p, intensity = 48.528, major = 2, channel = -1,
#  pitch = 69(time = 75-78), intensity sign = p, intensity = 43.242, major = 1, channel = -1,
#  pitch = 70(time = 75-78), intensity sign = pp, intensity = 27.763, major = 2, channel = -1,
#  pitch = 47(time = 76-82), intensity sign = p, intensity = 42.878, major = 1, channel = -1,
#  pitch = 47(time = 76-81), intensity sign = p, intensity = 43.979, major = 1, channel = -1,
#  pitch = 48(time = 76-79), intensity sign = pp, intensity = 26.965, major = 2, channel = -1,
#  pitch = 59(time = 76-79), intensity sign = pp, intensity = 29.637, major = 1, channel = -1,
#  pitch = 63(time = 76-79), intensity sign = p, intensity = 53.992, major = 2, channel = -1,
#  pitch = 66(time = 76-81), intensity sign = mp, intensity = 58.829, major = 1, channel = -1,
#  pitch = 66(time = 76-79), intensity sign = p, intensity = 54.304, major = 1, channel = -1,
#  pitch = 69(time = 76-79), intensity sign = mp, intensity = 64.367, major = 1, channel = -1,
#  pitch = 86(time = 76-79), intensity sign = pp, intensity = 27.285, major = 2, channel = -1,
#  pitch = 33(time = 77-92), intensity sign = mp, intensity = 58.526, major = 2, channel = -1,
#  pitch = 47(time = 77-82), intensity sign = pp, intensity = 35.163, major = 1, channel = -1,
#  pitch = 54(time = 77-80), intensity sign = pp, intensity = 29.091, major = 1, channel = -1,
#  pitch = 55(time = 77-80), intensity sign = ppp, intensity = 23.784, major = 2, channel = -1,
#  pitch = 59(time = 77-80), intensity sign = p, intensity = 45.687, major = 1, channel = -1,
#  pitch = 60(time = 77-80), intensity sign = pp, intensity = 30.485, major = 2, channel = -1,
#  pitch = 63(time = 77-80), intensity sign = p, intensity = 53.526, major = 1, channel = -1,
#  pitch = 66(time = 77-81), intensity sign = mp, intensity = 62.840, major = 1, channel = -1,
#  pitch = 69(time = 77-80), intensity sign = mp, intensity = 66.330, major = 2, channel = -1,
#  pitch = 32(time = 78-92), intensity sign = p, intensity = 46.379, major = 1, channel = -1,
#  pitch = 46(time = 78-84), intensity sign = pp, intensity = 37.275, major = 2, channel = -1,
#  pitch = 46(time = 78-83), intensity sign = pp, intensity = 32.259, major = 2, channel = -1,
#  pitch = 47(time = 78-83), intensity sign = pp, intensity = 30.689, major = 1, channel = -1,
#  pitch = 54(time = 78-81), intensity sign = pp, intensity = 33.063, major = 1, channel = -1,
#  pitch = 59(time = 78-81), intensity sign = p, intensity = 45.866, major = 1, channel = -1,
#  pitch = 63(time = 78-81), intensity sign = p, intensity = 44.490, major = 1, channel = -1,
#  pitch = 66(time = 78-81), intensity sign = mp, intensity = 61.248, major = 1, channel = -1,
#  pitch = 68(time = 78-81), intensity sign = p, intensity = 48.860, major = 1, channel = -1,
#  pitch = 69(time = 78-81), intensity sign = p, intensity = 49.367, major = 2, channel = -1,
#  pitch = 32(time = 79-92), intensity sign = mp, intensity = 58.730, major = 1, channel = -1,
#  pitch = 46(time = 79-84), intensity sign = p, intensity = 46.066, major = 2, channel = -1,
#  pitch = 54(time = 79-82), intensity sign = pp, intensity = 32.364, major = 1, channel = -1,
#  pitch = 59(time = 79-82), intensity sign = pp, intensity = 36.016, major = 1, channel = -1,
#  pitch = 62(time = 79-82), intensity sign = pp, intensity = 31.062, major = 2, channel = -1,
#  pitch = 63(time = 79-82), intensity sign = pp, intensity = 30.756, major = 1, channel = -1,
#  pitch = 66(time = 79-82), intensity sign = p, intensity = 41.519, major = 1, channel = -1,
#  pitch = 46(time = 80-84), intensity sign = p, intensity = 47.128, major = 2, channel = -1,
#  pitch = 53(time = 80-83), intensity sign = pp, intensity = 30.340, major = 2, channel = -1,
#  pitch = 54(time = 80-83), intensity sign = pp, intensity = 30.974, major = 1, channel = -1,
#  pitch = 58(time = 80-83), intensity sign = pp, intensity = 37.951, major = 2, channel = -1,
#  pitch = 62(time = 80-83), intensity sign = p, intensity = 47.296, major = 2, channel = -1,
#  pitch = 65(time = 80-83), intensity sign = pp, intensity = 36.130, major = 2, channel = -1,
#  pitch = 66(time = 80-83), intensity sign = pp, intensity = 31.775, major = 1, channel = -1,
#  pitch = 68(time = 80-83), intensity sign = f, intensity = 94.613, major = 1, channel = -1,
#  pitch = 31(time = 81-88), intensity sign = p, intensity = 41.384, major = 2, channel = -1,
#  pitch = 32(time = 81-90), intensity sign = p, intensity = 53.261, major = 1, channel = -1,
#  pitch = 45(time = 81-86), intensity sign = p, intensity = 41.094, major = 2, channel = -1,
#  pitch = 45(time = 81-85), intensity sign = pp, intensity = 34.902, major = 1, channel = -1,
#  pitch = 46(time = 81-85), intensity sign = pp, intensity = 36.504, major = 2, channel = -1,
#  pitch = 46(time = 81-84), intensity sign = p, intensity = 41.121, major = 2, channel = -1,
#  pitch = 53(time = 81-84), intensity sign = pp, intensity = 35.026, major = 2, channel = -1,
#  pitch = 58(time = 81-84), intensity sign = p, intensity = 41.842, major = 2, channel = -1,
#  pitch = 62(time = 81-84), intensity sign = p, intensity = 55.495, major = 2, channel = -1,
#  pitch = 65(time = 81-84), intensity sign = mp, intensity = 59.630, major = 2, channel = -1,
#  pitch = 67(time = 81-84), intensity sign = p, intensity = 42.699, major = 2, channel = -1,
#  pitch = 68(time = 81-84), intensity sign = mp, intensity = 60.329, major = 1, channel = -1,
#  pitch = 70(time = 81-84), intensity sign = mp, intensity = 62.359, major = 2, channel = -1,
#  pitch = 45(time = 82-88), intensity sign = p, intensity = 48.281, major = 2, channel = -1,
#  pitch = 45(time = 82-89), intensity sign = p, intensity = 49.163, major = 1, channel = -1,
#  pitch = 45(time = 82-86), intensity sign = p, intensity = 46.412, major = 2, channel = -1,
#  pitch = 53(time = 82-85), intensity sign = pp, intensity = 29.920, major = 2, channel = -1,
#  pitch = 58(time = 82-85), intensity sign = pp, intensity = 36.337, major = 2, channel = -1,
#  pitch = 61(time = 82-85), intensity sign = pp, intensity = 36.054, major = 1, channel = -1,
#  pitch = 62(time = 82-85), intensity sign = p, intensity = 43.206, major = 2, channel = -1,
#  pitch = 65(time = 82-85), intensity sign = mp, intensity = 57.152, major = 2, channel = -1,
#  pitch = 67(time = 82-85), intensity sign = p, intensity = 52.019, major = 2, channel = -1,
#  pitch = 70(time = 82-85), intensity sign = mp, intensity = 64.097, major = 2, channel = -1,
#  pitch = 72(time = 82-85), intensity sign = pp, intensity = 39.532, major = 2, channel = -1,
#  pitch = 31(time = 83-88), intensity sign = p, intensity = 48.755, major = 2, channel = -1,
#  pitch = 45(time = 83-88), intensity sign = p, intensity = 44.096, major = 1, channel = -1,
#  pitch = 52(time = 83-86), intensity sign = pp, intensity = 25.675, major = 1, channel = -1,
#  pitch = 53(time = 83-86), intensity sign = pp, intensity = 24.841, major = 2, channel = -1,
#  pitch = 57(time = 83-86), intensity sign = pp, intensity = 30.921, major = 2, channel = -1,
#  pitch = 58(time = 83-86), intensity sign = pp, intensity = 27.723, major = 2, channel = -1,
#  pitch = 61(time = 83-86), intensity sign = pp, intensity = 37.230, major = 1, channel = -1,
#  pitch = 64(time = 83-86), intensity sign = p, intensity = 43.337, major = 1, channel = -1,
#  pitch = 65(time = 83-86), intensity sign = pp, intensity = 37.006, major = 2, channel = -1,
#  pitch = 67(time = 83-86), intensity sign = p, intensity = 51.363, major = 2, channel = -1,
#  pitch = 69(time = 83-86), intensity sign = p, intensity = 49.926, major = 1, channel = -1,
#  pitch = 70(time = 83-86), intensity sign = p, intensity = 44.964, major = 2, channel = -1,
#  pitch = 71(time = 83-86), intensity sign = mp, intensity = 61.691, major = 1, channel = -1,
#  pitch = 72(time = 83-86), intensity sign = p, intensity = 42.744, major = 2, channel = -1,
#  pitch = 73(time = 83-86), intensity sign = pp, intensity = 39.327, major = 1, channel = -1,
#  pitch = 74(time = 83-86), intensity sign = pp, intensity = 27.606, major = 2, channel = -1,
#  pitch = 77(time = 83-86), intensity sign = pp, intensity = 25.828, major = 2, channel = -1,
#  pitch = 78(time = 83-86), intensity sign = pp, intensity = 36.314, major = 1, channel = -1,
#  pitch = 79(time = 83-86), intensity sign = pp, intensity = 29.282, major = 2, channel = -1,
#  pitch = 31(time = 84-88), intensity sign = pp, intensity = 29.276, major = 2, channel = -1,
#  pitch = 44(time = 84-88), intensity sign = p, intensity = 43.187, major = 1, channel = -1,
#  pitch = 52(time = 84-87), intensity sign = pp, intensity = 28.439, major = 1, channel = -1,
#  pitch = 57(time = 84-87), intensity sign = pp, intensity = 36.368, major = 2, channel = -1,
#  pitch = 64(time = 84-87), intensity sign = p, intensity = 40.994, major = 1, channel = -1,
#  pitch = 67(time = 84-87), intensity sign = pp, intensity = 37.229, major = 2, channel = -1,
#  pitch = 69(time = 84-87), intensity sign = p, intensity = 51.218, major = 1, channel = -1,
#  pitch = 71(time = 84-87), intensity sign = mp, intensity = 65.108, major = 1, channel = -1,
#  pitch = 73(time = 84-87), intensity sign = p, intensity = 46.205, major = 1, channel = -1,
#  pitch = 74(time = 84-88), intensity sign = mp, intensity = 59.947, major = 2, channel = -1,
#  pitch = 74(time = 84-87), intensity sign = p, intensity = 55.891, major = 2, channel = -1,
#  pitch = 74(time = 84-89), intensity sign = p, intensity = 42.175, major = 2, channel = -1,
#  pitch = 75(time = 84-87), intensity sign = pp, intensity = 39.332, major = 2, channel = -1,
#  pitch = 77(time = 84-87), intensity sign = pp, intensity = 25.382, major = 2, channel = -1,
#  pitch = 78(time = 84-87), intensity sign = pp, intensity = 30.015, major = 1, channel = -1,
#  pitch = 30(time = 85-88), intensity sign = pp, intensity = 37.392, major = 1, channel = -1,
#  pitch = 35(time = 85-88), intensity sign = ppp, intensity = 23.042, major = 1, channel = -1,
#  pitch = 44(time = 85-88), intensity sign = p, intensity = 40.246, major = 1, channel = -1,
#  pitch = 56(time = 85-88), intensity sign = pp, intensity = 34.833, major = 1, channel = -1,
#  pitch = 57(time = 85-88), intensity sign = pp, intensity = 30.112, major = 1, channel = -1,
#  pitch = 64(time = 85-88), intensity sign = pp, intensity = 29.033, major = 1, channel = -1,
#  pitch = 68(time = 85-88), intensity sign = ppp, intensity = 22.662, major = 1, channel = -1,
#  pitch = 69(time = 85-88), intensity sign = pp, intensity = 34.553, major = 2, channel = -1,
#  pitch = 70(time = 85-88), intensity sign = pp, intensity = 30.027, major = 2, channel = -1,
#  pitch = 71(time = 85-88), intensity sign = pp, intensity = 30.932, major = 1, channel = -1,
#  pitch = 72(time = 85-88), intensity sign = p, intensity = 46.862, major = 2, channel = -1,
#  pitch = 73(time = 85-88), intensity sign = pp, intensity = 36.176, major = 1, channel = -1,
#  pitch = 74(time = 85-89), intensity sign = mp, intensity = 71.728, major = 2, channel = -1,
#  pitch = 76(time = 85-88), intensity sign = pp, intensity = 29.497, major = 1, channel = -1,
#  pitch = 30(time = 86-89), intensity sign = pp, intensity = 29.171, major = 1, channel = -1,
#  pitch = 43(time = 86-89), intensity sign = pp, intensity = 30.470, major = 2, channel = -1,
#  pitch = 44(time = 86-89), intensity sign = pp, intensity = 29.925, major = 1, channel = -1,
#  pitch = 51(time = 86-89), intensity sign = pp, intensity = 26.338, major = 1, channel = -1,
#  pitch = 52(time = 86-89), intensity sign = ppp, intensity = 22.932, major = 1, channel = -1,
#  pitch = 56(time = 86-89), intensity sign = pp, intensity = 36.831, major = 1, channel = -1,
#  pitch = 70(time = 86-89), intensity sign = pp, intensity = 34.396, major = 2, channel = -1,
#  pitch = 72(time = 86-89), intensity sign = p, intensity = 49.566, major = 2, channel = -1,
#  pitch = 73(time = 86-89), intensity sign = p, intensity = 41.977, major = 1, channel = -1,
#  pitch = 74(time = 86-89), intensity sign = mp, intensity = 66.504, major = 2, channel = -1,
#  pitch = 74(time = 86-90), intensity sign = mp, intensity = 59.286, major = 2, channel = -1,
#  pitch = 75(time = 86-89), intensity sign = p, intensity = 48.849, major = 2, channel = -1,
#  pitch = 76(time = 86-89), intensity sign = pp, intensity = 25.994, major = 1, channel = -1,
#  pitch = 29(time = 87-90), intensity sign = pp, intensity = 25.925, major = 2, channel = -1,
#  pitch = 43(time = 87-90), intensity sign = pp, intensity = 31.207, major = 2, channel = -1,
#  pitch = 51(time = 87-90), intensity sign = pp, intensity = 28.281, major = 1, channel = -1,
#  pitch = 56(time = 87-90), intensity sign = pp, intensity = 35.043, major = 1, channel = -1,
#  pitch = 70(time = 87-90), intensity sign = pp, intensity = 34.878, major = 2, channel = -1,
#  pitch = 72(time = 87-90), intensity sign = p, intensity = 46.788, major = 2, channel = -1,
#  pitch = 73(time = 87-90), intensity sign = p, intensity = 41.699, major = 1, channel = -1,
#  pitch = 74(time = 87-90), intensity sign = pp, intensity = 38.646, major = 2, channel = -1,
#  pitch = 75(time = 87-90), intensity sign = p, intensity = 52.928, major = 2, channel = -1,
#  pitch = 34(time = 88-92), intensity sign = mp, intensity = 60.837, major = 2, channel = -1,
#  pitch = 45(time = 88-91), intensity sign = pp, intensity = 31.294, major = 1, channel = -1,
#  pitch = 51(time = 88-91), intensity sign = pp, intensity = 26.282, major = 2, channel = -1,
#  pitch = 56(time = 88-91), intensity sign = ppp, intensity = 23.412, major = 1, channel = -1,
#  pitch = 73(time = 88-91), intensity sign = pp, intensity = 36.113, major = 1, channel = -1,
#  pitch = 74(time = 88-91), intensity sign = p, intensity = 44.075, major = 2, channel = -1,
#  pitch = 75(time = 88-91), intensity sign = p, intensity = 46.523, major = 1, channel = -1,
#  pitch = 76(time = 88-91), intensity sign = pp, intensity = 34.406, major = 1, channel = -1,
#  pitch = 35(time = 89-92), intensity sign = mf, intensity = 73.941, major = 1, channel = -1,
#  pitch = 36(time = 89-92), intensity sign = mp, intensity = 67.463, major = 2, channel = -1,
#  pitch = 39(time = 89-92), intensity sign = pp, intensity = 24.747, major = 2, channel = -1,
#  pitch = 40(time = 89-92), intensity sign = pp, intensity = 31.434, major = 1, channel = -1,
#  pitch = 41(time = 89-92), intensity sign = pp, intensity = 31.322, major = 2, channel = -1,
#  pitch = 45(time = 89-92), intensity sign = pp, intensity = 26.190, major = 1, channel = -1,
#  pitch = 46(time = 89-92), intensity sign = pp, intensity = 30.966, major = 2, channel = -1,
#  pitch = 75(time = 89-92), intensity sign = pp, intensity = 26.902, major = 2, channel = -1,
#  pitch = 76(time = 89-92), intensity sign = pp, intensity = 37.345, major = 1, channel = -1,
#  pitch = 31(time = 90-93), intensity sign = pp, intensity = 30.072, major = 2, channel = -1,
#  pitch = 36(time = 90-93), intensity sign = mp, intensity = 64.949, major = 2, channel = -1,
#  pitch = 37(time = 90-93), intensity sign = p, intensity = 47.945, major = 1, channel = -1,
#  pitch = 74(time = 90-93), intensity sign = pp, intensity = 24.428, major = 2, channel = -1,
#  pitch = 38(time = 91-94), intensity sign = pp, intensity = 24.734, major = 2, channel = -1,
#  pitch = 32(time = 92-95), intensity sign = pp, intensity = 27.484, major = 1, channel = -1,
#  pitch = 33(time = 118-121), intensity sign = pp, intensity = 33.842, major = 1, channel = -1,
#  pitch = 34(time = 118-121), intensity sign = p, intensity = 53.009, major = 2, channel = -1,
#  pitch = 35(time = 118-121), intensity sign = mf, intensity = 73.811, major = 1, channel = -1,
# ...
#  pitch = 25(time = 180-183), intensity sign = pp, intensity = 35.520, major = 1, channel = -1,
#  pitch = 32(time = 180-185), intensity sign = p, intensity = 51.249, major = 1, channel = -1,
#  pitch = 33(time = 180-185), intensity sign = mp, intensity = 68.939, major = 1, channel = -1,
#  pitch = 35(time = 180-185), intensity sign = mp, intensity = 68.741, major = 1, channel = -1,
#  pitch = 36(time = 180-185), intensity sign = mp, intensity = 64.400, major = 2, channel = -1,
#  pitch = 36(time = 180-183), intensity sign = mp, intensity = 64.003, major = 2, channel = -1,
#  pitch = 37(time = 180-183), intensity sign = mp, intensity = 57.657, major = 1, channel = -1,
#  pitch = 38(time = 180-183), intensity sign = pp, intensity = 38.861, major = 2, channel = -1,
#  pitch = 38(time = 181-184), intensity sign = p, intensity = 49.887, major = 2, channel = -1,
#  pitch = 39(time = 181-184), intensity sign = p, intensity = 40.570, major = 2, channel = -1,
#  pitch = 40(time = 181-184), intensity sign = pp, intensity = 29.799, major = 1, channel = -1,
#  pitch = 24(time = 182-185), intensity sign = pp, intensity = 26.475, major = 2, channel = -1,
#  pitch = 25(time = 182-185), intensity sign = pp, intensity = 32.663, major = 1, channel = -1,
#  pitch = 26(time = 182-185), intensity sign = pp, intensity = 36.405, major = 2, channel = -1,
#  pitch = 27(time = 182-185), intensity sign = pp, intensity = 27.686, major = 1, channel = -1,
#  pitch = 31(time = 183-186), intensity sign = p, intensity = 43.995, major = 2, channel = -1,
#  pitch = 32(time = 183-186), intensity sign = mp, intensity = 57.343, major = 1, channel = -1,
#  pitch = 39(time = 183-186), intensity sign = pp, intensity = 31.305, major = 2, channel = -1,
#  pitch = 40(time = 183-186), intensity sign = pp, intensity = 33.462, major = 1, channel = -1,
#  pitch = 41(time = 183-186), intensity sign = pp, intensity = 27.892, major = 2, channel = -1,
#  pitch = 36(time = 184-187), intensity sign = p, intensity = 48.194, major = 2, channel = -1,
#  pitch = 37(time = 184-187), intensity sign = pp, intensity = 35.774, major = 1, channel = -1,
#  pitch = 38(time = 184-187), intensity sign = pp, intensity = 29.510, major = 2, channel = -1,
#  pitch = 30(time = 185-188), intensity sign = pp, intensity = 28.226, major = 1, channel = -1,
#  pitch = 78(time = 208-211), intensity sign = pp, intensity = 37.602, major = 1, channel = -1,
#  pitch = 79(time = 208-211), intensity sign = p, intensity = 43.946, major = 2, channel = -1,
#  pitch = 80(time = 208-211), intensity sign = pp, intensity = 31.989, major = 1, channel = -1,
#  pitch = 82(time = 208-211), intensity sign = p, intensity = 43.653, major = 2, channel = -1,
#  pitch = 83(time = 208-211), intensity sign = pp, intensity = 34.197, major = 1, channel = -1,
#  pitch = 85(time = 208-211), intensity sign = pp, intensity = 29.506, major = 1, channel = -1,
#  pitch = 86(time = 208-211), intensity sign = p, intensity = 40.456, major = 2, channel = -1,
#  pitch = 77(time = 209-212), intensity sign = pp, intensity = 29.677, major = 2, channel = -1,
#  pitch = 78(time = 209-212), intensity sign = pp, intensity = 37.657, major = 1, channel = -1,
#  pitch = 82(time = 209-212), intensity sign = p, intensity = 42.704, major = 2, channel = -1,
#  pitch = 83(time = 209-212), intensity sign = pp, intensity = 34.814, major = 1, channel = -1,
#  pitch = 79(time = 209-212), intensity sign = p, intensity = 45.490, major = 2, channel = -1,
#  pitch = 80(time = 209-212), intensity sign = pp, intensity = 33.486, major = 1, channel = -1,
#  pitch = 81(time = 209-212), intensity sign = pp, intensity = 30.476, major = 1, channel = -1,
#  pitch = 84(time = 209-212), intensity sign = pp, intensity = 33.176, major = 2, channel = -1,
#  pitch = 85(time = 209-212), intensity sign = pp, intensity = 29.582, major = 1, channel = -1,
#  pitch = 86(time = 209-212), intensity sign = p, intensity = 43.316, major = 2, channel = -1,
#  pitch = 87(time = 209-212), intensity sign = pp, intensity = 30.634, major = 2, channel = -1,
#  pitch = 77(time = 210-213), intensity sign = pp, intensity = 29.576, major = 2, channel = -1,
#  pitch = 79(time = 210-213), intensity sign = pp, intensity = 34.902, major = 2, channel = -1,
#  pitch = 82(time = 210-213), intensity sign = pp, intensity = 33.262, major = 2, channel = -1,
#  pitch = 83(time = 210-213), intensity sign = pp, intensity = 33.782, major = 1, channel = -1,
#  pitch = 78(time = 210-213), intensity sign = pp, intensity = 25.911, major = 1, channel = -1,
#  pitch = 80(time = 210-213), intensity sign = pp, intensity = 25.130, major = 1, channel = -1,
#  pitch = 81(time = 210-213), intensity sign = pp, intensity = 24.996, major = 1, channel = -1,
#  pitch = 84(time = 210-213), intensity sign = pp, intensity = 28.043, major = 2, channel = -1,
#  pitch = 85(time = 210-213), intensity sign = pp, intensity = 25.747, major = 1, channel = -1,
#  pitch = 86(time = 210-213), intensity sign = pp, intensity = 36.355, major = 2, channel = -1,
#  pitch = 30(time = 211-214), intensity sign = p, intensity = 48.100, major = 1, channel = -1,
#  pitch = 31(time = 211-214), intensity sign = mp, intensity = 61.983, major = 2, channel = -1,
#  pitch = 32(time = 211-214), intensity sign = mp, intensity = 63.694, major = 1, channel = -1,
#  pitch = 33(time = 211-214), intensity sign = mp, intensity = 56.348, major = 2, channel = -1,
#  pitch = 34(time = 211-214), intensity sign = p, intensity = 49.537, major = 2, channel = -1,
#  pitch = 35(time = 211-214), intensity sign = p, intensity = 49.082, major = 1, channel = -1,
#  pitch = 36(time = 211-214), intensity sign = p, intensity = 46.621, major = 2, channel = -1,
#  pitch = 37(time = 211-214), intensity sign = p, intensity = 42.660, major = 1, channel = -1,
#  pitch = 38(time = 211-214), intensity sign = pp, intensity = 39.181, major = 2, channel = -1,
#  pitch = 39(time = 211-214), intensity sign = pp, intensity = 36.316, major = 1, channel = -1,
#  pitch = 40(time = 211-214), intensity sign = pp, intensity = 34.811, major = 1, channel = -1,
#  pitch = 41(time = 211-214), intensity sign = pp, intensity = 32.992, major = 2, channel = -1,
#  pitch = 42(time = 211-214), intensity sign = pp, intensity = 31.917, major = 1, channel = -1,
#  pitch = 43(time = 211-214), intensity sign = p, intensity = 41.460, major = 2, channel = -1,
#  pitch = 44(time = 211-214), intensity sign = p, intensity = 46.689, major = 1, channel = -1,
#  pitch = 77(time = 211-214), intensity sign = pp, intensity = 30.008, major = 2, channel = -1,
#  pitch = 83(time = 211-214), intensity sign = pp, intensity = 24.276, major = 1, channel = -1,
#  pitch = 28(time = 212-215), intensity sign = pp, intensity = 28.741, major = 1, channel = -1,
#  pitch = 29(time = 212-215), intensity sign = p, intensity = 40.345, major = 2, channel = -1,
#  pitch = 30(time = 212-215), intensity sign = p, intensity = 51.384, major = 1, channel = -1,
#  pitch = 44(time = 212-215), intensity sign = pp, intensity = 30.236, major = 1, channel = -1,
#  pitch = 45(time = 212-215), intensity sign = pp, intensity = 39.166, major = 2, channel = -1,
#  pitch = 46(time = 212-215), intensity sign = pp, intensity = 38.819, major = 2, channel = -1,
#  pitch = 47(time = 212-215), intensity sign = pp, intensity = 29.233, major = 1, channel = -1,
#  pitch = 37(time = 213-216), intensity sign = pp, intensity = 33.862, major = 1, channel = -1,
#  pitch = 32(time = 215-218), intensity sign = pp, intensity = 28.687, major = 1, channel = -1,
#  pitch = 33(time = 215-218), intensity sign = ppp, intensity = 23.928, major = 1, channel = -1,
#  pitch = 34(time = 216-219), intensity sign = mp, intensity = 62.572, major = 2, channel = -1,
#  pitch = 35(time = 216-219), intensity sign = p, intensity = 47.837, major = 1, channel = -1,
#  pitch = 36(time = 216-219), intensity sign = pp, intensity = 38.215, major = 2, channel = -1,
#  pitch = 28(time = 217-220), intensity sign = pp, intensity = 29.077, major = 1, channel = -1,
#  pitch = 29(time = 217-220), intensity sign = pp, intensity = 34.637, major = 2, channel = -1,
#  pitch = 29(time = 217-222), intensity sign = mp, intensity = 58.579, major = 2, channel = -1,
#  pitch = 30(time = 217-222), intensity sign = mp, intensity = 60.596, major = 1, channel = -1,
#  pitch = 31(time = 217-222), intensity sign = pp, intensity = 36.102, major = 2, channel = -1,
#  pitch = 31(time = 217-223), intensity sign = mp, intensity = 65.652, major = 2, channel = -1,
#  pitch = 32(time = 217-223), intensity sign = mp, intensity = 71.148, major = 1, channel = -1,
#  pitch = 33(time = 217-220), intensity sign = mp, intensity = 70.663, major = 2, channel = -1,
#  pitch = 34(time = 217-220), intensity sign = p, intensity = 55.415, major = 2, channel = -1,
#  pitch = 36(time = 217-220), intensity sign = pp, intensity = 36.848, major = 2, channel = -1,
#  pitch = 37(time = 217-220), intensity sign = pp, intensity = 29.784, major = 1, channel = -1,
#  pitch = 43(time = 217-220), intensity sign = p, intensity = 51.232, major = 2, channel = -1,
#  pitch = 44(time = 217-220), intensity sign = mp, intensity = 58.152, major = 1, channel = -1,
#  pitch = 45(time = 217-220), intensity sign = mp, intensity = 61.569, major = 1, channel = -1,
#  pitch = 46(time = 217-220), intensity sign = p, intensity = 47.664, major = 2, channel = -1,
#  pitch = 47(time = 217-220), intensity sign = pp, intensity = 38.931, major = 1, channel = -1,
#  pitch = 48(time = 217-220), intensity sign = pp, intensity = 31.826, major = 2, channel = -1,
#  pitch = 51(time = 217-220), intensity sign = pp, intensity = 37.268, major = 2, channel = -1,
#  pitch = 52(time = 217-220), intensity sign = p, intensity = 45.099, major = 1, channel = -1,
#  pitch = 53(time = 217-220), intensity sign = pp, intensity = 38.009, major = 2, channel = -1,
#  pitch = 56(time = 217-220), intensity sign = p, intensity = 49.395, major = 1, channel = -1,
#  pitch = 57(time = 217-220), intensity sign = pp, intensity = 30.546, major = 1, channel = -1,
#  pitch = 75(time = 217-220), intensity sign = pp, intensity = 24.753, major = 2, channel = -1,
#  pitch = 77(time = 217-220), intensity sign = pp, intensity = 30.961, major = 2, channel = -1,
#  pitch = 43(time = 218-221), intensity sign = p, intensity = 44.869, major = 2, channel = -1,
#  pitch = 51(time = 218-221), intensity sign = pp, intensity = 26.512, major = 1, channel = -1,
#  pitch = 55(time = 218-221), intensity sign = pp, intensity = 26.250, major = 2, channel = -1,
#  pitch = 56(time = 218-221), intensity sign = p, intensity = 45.645, major = 1, channel = -1,
#  pitch = 57(time = 218-221), intensity sign = pp, intensity = 27.455, major = 2, channel = -1,
#  pitch = 75(time = 218-221), intensity sign = pp, intensity = 31.618, major = 1, channel = -1,
#  pitch = 78(time = 218-222), intensity sign = p, intensity = 42.110, major = 1, channel = -1,
#  pitch = 78(time = 218-221), intensity sign = pp, intensity = 28.801, major = 1, channel = -1,
#  pitch = 79(time = 218-222), intensity sign = pp, intensity = 30.328, major = 2, channel = -1,
#  pitch = 79(time = 218-221), intensity sign = pp, intensity = 27.246, major = 2, channel = -1,
#  pitch = 28(time = 219-222), intensity sign = p, intensity = 49.496, major = 1, channel = -1,
#  pitch = 29(time = 219-222), intensity sign = p, intensity = 50.770, major = 2, channel = -1,
#  pitch = 42(time = 219-222), intensity sign = pp, intensity = 38.907, major = 1, channel = -1,
#  pitch = 43(time = 219-222), intensity sign = pp, intensity = 30.743, major = 2, channel = -1,
#  pitch = 55(time = 219-222), intensity sign = pp, intensity = 31.474, major = 2, channel = -1,
#  pitch = 58(time = 219-222), intensity sign = p, intensity = 47.170, major = 2, channel = -1,
#  pitch = 59(time = 219-222), intensity sign = p, intensity = 45.011, major = 1, channel = -1,
#  pitch = 60(time = 219-222), intensity sign = pp, intensity = 26.025, major = 2, channel = -1,
#  pitch = 75(time = 219-222), intensity sign = pp, intensity = 27.550, major = 2, channel = -1,
#  pitch = 77(time = 219-222), intensity sign = pp, intensity = 39.499, major = 2, channel = -1,
#  pitch = 78(time = 219-222), intensity sign = p, intensity = 50.294, major = 1, channel = -1,
#  pitch = 79(time = 219-222), intensity sign = p, intensity = 40.383, major = 2, channel = -1,
#  pitch = 26(time = 220-223), intensity sign = pp, intensity = 28.393, major = 2, channel = -1,
#  pitch = 27(time = 220-223), intensity sign = pp, intensity = 38.825, major = 1, channel = -1,
#  pitch = 28(time = 220-223), intensity sign = p, intensity = 46.412, major = 1, channel = -1,
#  pitch = 40(time = 220-223), intensity sign = pp, intensity = 32.245, major = 1, channel = -1,
#  pitch = 41(time = 220-223), intensity sign = p, intensity = 42.236, major = 2, channel = -1,
#  pitch = 42(time = 220-223), intensity sign = pp, intensity = 29.347, major = 1, channel = -1,
#  pitch = 53(time = 220-223), intensity sign = pp, intensity = 24.467, major = 2, channel = -1,
#  pitch = 54(time = 220-223), intensity sign = pp, intensity = 25.168, major = 1, channel = -1,
#  pitch = 56(time = 220-223), intensity sign = pp, intensity = 26.486, major = 1, channel = -1,
#  pitch = 57(time = 220-223), intensity sign = pp, intensity = 35.907, major = 2, channel = -1,
#  pitch = 58(time = 220-223), intensity sign = p, intensity = 45.401, major = 2, channel = -1,
#  pitch = 75(time = 220-223), intensity sign = ppp, intensity = 23.850, major = 1, channel = -1,
#  pitch = 76(time = 220-223), intensity sign = pp, intensity = 28.775, major = 1, channel = -1,
#  pitch = 77(time = 220-223), intensity sign = p, intensity = 40.533, major = 2, channel = -1,
#  pitch = 78(time = 220-223), intensity sign = pp, intensity = 30.390, major = 1, channel = -1,
#  pitch = 79(time = 220-223), intensity sign = p, intensity = 46.608, major = 2, channel = -1,
#  pitch = 80(time = 220-223), intensity sign = pp, intensity = 34.152, major = 1, channel = -1,
#  pitch = 81(time = 220-223), intensity sign = pp, intensity = 25.859, major = 2, channel = -1,
#  pitch = 82(time = 220-223), intensity sign = pp, intensity = 28.314, major = 2, channel = -1,
#  pitch = 39(time = 221-224), intensity sign = pp, intensity = 29.838, major = 1, channel = -1,
#  pitch = 40(time = 221-224), intensity sign = pp, intensity = 27.177, major = 1, channel = -1,
#  pitch = 56(time = 221-224), intensity sign = pp, intensity = 31.757, major = 1, channel = -1,
#  pitch = 78(time = 221-224), intensity sign = pp, intensity = 39.138, major = 1, channel = -1,
#  pitch = 79(time = 221-224), intensity sign = pp, intensity = 24.669, major = 2, channel = -1,
#  pitch = 82(time = 221-224), intensity sign = pp, intensity = 30.859, major = 2, channel = -1,
#  pitch = 33(time = 222-225), intensity sign = pp, intensity = 27.792, major = 2, channel = -1,
#  pitch = 34(time = 222-225), intensity sign = pp, intensity = 28.365, major = 2, channel = -1,
#  pitch = 35(time = 222-225), intensity sign = pp, intensity = 33.307, major = 1, channel = -1,
#  pitch = 36(time = 222-225), intensity sign = pp, intensity = 32.854, major = 2, channel = -1,
#  pitch = 37(time = 222-225), intensity sign = pp, intensity = 28.570, major = 1, channel = -1,
#  pitch = 79(time = 222-225), intensity sign = pp, intensity = 33.769, major = 2, channel = -1,
#  pitch = 33(time = 223-226), intensity sign = pp, intensity = 34.269, major = 1, channel = -1,
#  pitch = 34(time = 223-226), intensity sign = pp, intensity = 30.534, major = 2, channel = -1,
#  pitch = 79(time = 223-226), intensity sign = pp, intensity = 29.531, major = 2, channel = -1,
#  pitch = 33(time = 225-228), intensity sign = pp, intensity = 33.619, major = 2, channel = -1,
#  pitch = 34(time = 225-228), intensity sign = pp, intensity = 29.763, major = 2, channel = -1,
#  pitch = 31(time = 226-229), intensity sign = pp, intensity = 26.019, major = 2, channel = -1,
#  pitch = 32(time = 226-229), intensity sign = pp, intensity = 32.251, major = 1, channel = -1,
#  pitch = 33(time = 226-229), intensity sign = pp, intensity = 26.816, major = 1, channel = -1,
#  pitch = 34(time = 227-230), intensity sign = pp, intensity = 27.060, major = 2, channel = -1]
# 854

# %%
word_gap = 15
def separate_word(notes,word_gap):
    word_list = []
    ptr = 0
    for i in range(len(notes)-1):
        if notes[i+1].start - notes[i].end >= word_gap:
            word_list.append(notes[ptr:i+1])
            ptr = i + 1
        if i == len(notes) - 2:
            word_list.append(notes[ptr:])
    return word_list

# %%
def check_handshape(pitchs,righthand):
    n = len(pitchs) #number of notes in the group
    pitchs.sort()
    constraints = {'12': 9, '13': 12, '14': 12, '15': 12, '23': 7, '24': 8, '25': 10, '34': 5, '35': 7, '45': 4}
    if n < 3:
        return True
    if righthand:
        #right hand
        if n == 3:
            if pitchs[-1]-pitchs[-2] > 9: return False
            return True
        if n == 4:
            g1 = pitchs[1] - pitchs[0] 
            g2 = pitchs[2] - pitchs[1] 
            g3 = pitchs[3] - pitchs[2] 
            g4 = pitchs[2] - pitchs[0]
            g5 = pitchs[3] - pitchs[1]
            g6 = pitchs[3] - pitchs[0]
            #1234
            if g1 <= constraints['12'] and g2 <= constraints['23'] and g3 <= constraints['34'] and g4 <= constraints['13'] and g5 <= constraints['24'] and g6 <= constraints['14']:
                return True
            #1235
            elif g1 <= constraints['12'] and g2 <= constraints['23'] and g3 <= constraints['35'] and g4 <= constraints['13'] and g5 <= constraints['25'] and g6 <= constraints['15']:
                return True
            #1245
            elif g1 <= constraints['12'] and g2 <= constraints['24'] and g3 <= constraints['45'] and g4 <= constraints['14'] and g5 <= constraints['25'] and g6 <= constraints['15']:
                return True
            #1345
            elif g1 <= constraints['13'] and g2 <= constraints['34'] and g3 <= constraints['45'] and g4 <= constraints['14'] and g5 <= constraints['35'] and g6 <= constraints['15']:
                return True
            #2345
            elif g1 <= constraints['23'] and g2 <= constraints['34'] and g3 <= constraints['45'] and g4 <= constraints['24'] and g5 <= constraints['35'] and g6 <= constraints['25']:
                return True
            return False
        if n == 5:
            g1 = (pitchs[1] - pitchs[0]) <= constraints['12']
            g2 = (pitchs[2] - pitchs[0]) <= constraints['13']
            g3 = (pitchs[3] - pitchs[0]) <= constraints['14']
            g4 = (pitchs[4] - pitchs[0]) <= constraints['15']
            g5 = (pitchs[2] - pitchs[1]) <= constraints['23']
            g6 = (pitchs[3] - pitchs[1]) <= constraints['24']
            g7 = (pitchs[4] - pitchs[1]) <= constraints['25']
            g8 = (pitchs[3] - pitchs[2]) <= constraints['34']
            g9 = (pitchs[4] - pitchs[2]) <= constraints['35']
            g10 = (pitchs[4] - pitchs[3]) <= constraints['45']
            return all([g1, g2, g3, g4, g5, g6, g7, g8, g9, g10])
    else:
        #left hand
        if n == 3:
            if pitchs[1]-pitchs[0] > 9: return False
            return True
        if n == 4:
            g1 = pitchs[1] - pitchs[0] 
            g2 = pitchs[2] - pitchs[1] 
            g3 = pitchs[3] - pitchs[2] 
            g4 = pitchs[2] - pitchs[0]
            g5 = pitchs[3] - pitchs[1]
            g6 = pitchs[3] - pitchs[0]
            #4321
            if g1 <= constraints['34'] and g2 <= constraints['23'] and g3 <= constraints['12'] and g4 <= constraints['24'] and g5 <= constraints['13'] and g6 <= constraints['14']:
                return True
            #5321
            elif g1 <= constraints['35'] and g2 <= constraints['23'] and g3 <= constraints['12'] and g4 <= constraints['25'] and g5 <= constraints['13'] and g6 <= constraints['15']:
                return True
            #5421
            elif g1 <= constraints['45'] and g2 <= constraints['24'] and g3 <= constraints['12'] and g4 <= constraints['25'] and g5 <= constraints['14'] and g6 <= constraints['15']:
                return True
            #5431
            elif g1 <= constraints['45'] and g2 <= constraints['34'] and g3 <= constraints['13'] and g4 <= constraints['35'] and g5 <= constraints['14'] and g6 <= constraints['15']:
                return True
            #5432
            elif g1 <= constraints['45'] and g2 <= constraints['34'] and g3 <= constraints['23'] and g4 <= constraints['35'] and g5 <= constraints['24'] and g6 <= constraints['25']:
                return True
            return False
        if n == 5:
            g1 = (pitchs[1] - pitchs[0]) <= constraints['45']
            g2 = (pitchs[2] - pitchs[0]) <= constraints['35']
            g3 = (pitchs[3] - pitchs[0]) <= constraints['25']
            g4 = (pitchs[4] - pitchs[0]) <= constraints['15']
            g5 = (pitchs[2] - pitchs[1]) <= constraints['34']
            g6 = (pitchs[3] - pitchs[1]) <= constraints['24']
            g7 = (pitchs[4] - pitchs[1]) <= constraints['14']
            g8 = (pitchs[3] - pitchs[2]) <= constraints['23']
            g9 = (pitchs[4] - pitchs[2]) <= constraints['13']
            g10 = (pitchs[4] - pitchs[3]) <= constraints['12']
            return all([g1, g2, g3, g4, g5, g6, g7, g8, g9, g10])
    print('Group not valid')
    return False

# %%
def valid_note_to_allocate(note,righthand,pitch_group,high):
    test_group = pitch_group + [note.pitch]
    if not check_handshape(test_group,righthand):
        if len(test_group) == 6:
            print(pitch_group)
            print(test_group)
        return False
    low = note.pitch if pitch_group == [] else min(pitch_group)
    
    if (note.pitch not in pitch_group) and (note.pitch-low <= 12):
        #q remain: limit highest note range?
        if righthand and note.pitch < (high + 1):
            return False
        return True
    return False

def valid_to_add(candidate,current_group):
    # numel = sum([len(x) for x in candidate])
    # c1 = counter < numel
    c1 = (not empty_list(candidate))
    c2 = len(current_group) < 5
    return c1 and c2

# %%
def priority(note, current_allocated_note,major = 'None'):
    c1 = note.intensity_sign == current_allocated_note.intensity_sign
    c2 = (note.start == current_allocated_note.start and note.end == current_allocated_note.end)
    # c3 =  note.major == major

    if c1 and c2:
        return 1
    elif c1 and (not c2):
        return 2
    elif c2 and (not c1):
        return 3
    else: return 4

# %%
class Pianist:
    def __init__(self, num, starttime = None, tempo = None):
        self.num = num + 1
        self.leftnotes = []
        self.rightnotes = []
        self.starttime = starttime
        self.tempo = tempo
        self.lendtime = 0
        self.rendtime = 0
        self.high = 0

    def __repr__(self):
        return f"Pianist No.{self.num}. Tempo = {self.tempo}bpm, starting time = {self.starttime}"
    
    def addleft(self,notes):
        self.leftnotes.extend(notes)
        end = max([note.end for note in notes])
        self.lendtime = max(self.lendtime, end)

    def addright(self,notes):
        self.rightnotes.extend(notes)
        end = max([note.end for note in notes])
        self.rendtime = max(self.rendtime, end)

    def endtimes(self):
        print('Pianist No.', self.num)
        print('left ending time =', self.lendtime, 'right ending time =', self.rendtime)
        
    def printnotes(self):
        print('Pianist No.', self.num)
        print('Left hand')
        pprint(self.leftnotes)
        print('Right hand')
        pprint(self.rightnotes)

# %%
def init_pianists():
    pianists = []
    for i in range(21):
        pianists.append(Pianist(i))
    return pianists

# %%
note1 = Note(34,0,4,0)
note2 = Note(33,0,5,0)
note3 = Note(33,0,4,0)
note = [note1, note2, note3]
minnote = min(note, key = lambda note: note.pitch)
print(minnote)

# %%
def allocation(cur_pianist, righthand, notes_group, tempo = None):
    current_group = []
    pitch_group = []

    if not righthand:
        endtime = cur_pianist.lendtime
    else:
        endtime = cur_pianist.rendtime
    
    start_time = endtime + min_frame_gap

    valid_notes_group = [note for note in notes_group if note.start >= start_time]
    if valid_notes_group == []:
        return notes_group, 0
    
    if not righthand:
        high = 0
        minnote = min(valid_notes_group, key = lambda note: note.pitch)
        pitch_group = [minnote.pitch]
        #major = minnote.major
        current_group.append(minnote)
        valid_notes_group.remove(minnote)
    else:
        high = cur_pianist.high
        for i in range(len(valid_notes_group)):
            if valid_notes_group[i].pitch > (high + 1):
                pitch_group = [valid_notes_group[i].pitch]
                current_group.append(valid_notes_group.pop(i))
                break
    candidate = [[],[],[],[]]   #4 priority groups for candidates         
    for current_allocated_note in current_group:
        if len(current_group) >= 5:
            break
        candidate = [[],[],[],[]]
        for note in valid_notes_group:
            if not valid_note_to_allocate(note,righthand,pitch_group,high):
                continue
            p = priority(note,current_allocated_note)
            candidate[p-1].append(note)


        for i in range(2): 
            #only consider the top two priority groups here
            #still notes in candidate list, current_group has not been filled up
            while valid_to_add(candidate[i],current_group):
                cur_candidates = candidate[i]
                shuffle_note = cur_candidates[random.randint(0, len(cur_candidates)-1)]
                candidate[i].remove(shuffle_note)
                if shuffle_note.pitch not in pitch_group:
                    if len(current_group) >= 2:
                        test_group = pitch_group + [shuffle_note.pitch]
                        if not check_handshape(test_group,righthand):
                            continue
                    pitch_group.append(shuffle_note.pitch)
                    current_group.append(shuffle_note)
                    valid_notes_group.remove(shuffle_note)

    for i in range(len(candidate)): 
        while valid_to_add(candidate[i],current_group):
            cur_candidates = candidate[i]
            shuffle_note = cur_candidates[random.randint(0, len(cur_candidates)-1)]
            candidate[i].remove(shuffle_note)
            if shuffle_note.pitch not in pitch_group:
                if len(current_group) >= 2:
                    test_group = pitch_group + [shuffle_note.pitch]
                    if not check_handshape(test_group,righthand):
                        continue
                pitch_group.append(shuffle_note.pitch)
                current_group.append(shuffle_note)
                valid_notes_group.remove(shuffle_note)

    if current_group != [] and (not righthand):
        high = max([n.pitch for n in current_group])
        cur_pianist.high = high
        
    if righthand:
        cur_pianist.addright(current_group)
    else:
        if cur_pianist.starttime == None:
            cur_pianist.starttime = min([n.start for n in current_group])
        cur_pianist.addleft(current_group)

    for note in current_group:
        notes_group.remove(note)


    return notes_group

# %%
def current_pianist(pianists):
    num = 0
    righthand = False
    endtime = pianists[0].lendtime
    for idx, pianist in enumerate(pianists):
        if pianist.lendtime == 0:
            return pianist, False
        elif pianist.rendtime == 0:
            return pianist, True
        
        if pianist.lendtime <= endtime:
            righthand = False
            num = idx
        elif pianist.rendtime <= endtime:
            righthand = True
            num = idx
    
    return pianists[num], righthand

# %%
def allocation_all(notes_group,pianists):
    righthand = False
    #notes = sorted(notes, key = lambda note: (note.start, note.pitch))
    while notes_group != []:
        previous = copy.deepcopy(notes_group)
        cur_pianist, righthand = current_pianist(pianists)
        cur_pianist.endtimes()
        
        
        #allocate left hand
        notes_group = allocation(cur_pianist, righthand, notes_group)
        #allocate right hand
        righthand = not righthand
        notes_group = allocation(cur_pianist, righthand, notes_group)

        if len(notes_group) == len(previous):
            break
    
    #补全剩余的notes


    if notes_group != []:
        print('Failed :(    ',len(notes_group), 'notes unallocated.')
        if len(notes_group) < 113:
            return True
        return False
    else:
        print('Success!')
        return True

# %%
def allocation_all_old(notes_group):
    allocate_result=[]
    group = 1
    righthand = False #true if last group was left hand, current group is right hand, they should not overlap
    while notes_group != [] and group <= group_num:
        ## each while iteration allocate one group
        current_group = []
        pitch_group = []
        
        if not righthand:
            high = 0
            minnote = min(notes_group, key = lambda note: note.pitch)
            pitch_group = [minnote.pitch]
            major = minnote.major
            current_group.append(minnote)
            notes_group.remove(minnote)
        else:
            for i in range(len(notes_group)):
                if notes_group[i].pitch > (high + 1):
                    pitch_group = [notes_group[i].pitch]
                    current_group.append(notes_group.pop(i))
                    break
        candidate = [[],[],[],[]]   #4 priority groups for candidates         
        for current_allocated_note in current_group:
            if len(current_group) >= 5:
                break
            candidate = [[],[],[],[]]
            for note in notes_group:
                if not valid_note_to_allocate(note,righthand,pitch_group,high):
                    continue
                p = priority(note,current_allocated_note,major)
                candidate[p-1].append(note)


            for i in range(2): 
                #still notes in candidate list, current_group has not been filled up
                while valid_to_add(candidate[i],current_group):
                    cur_candidates = candidate[i]
                    shuffle_note = cur_candidates[random.randint(0, len(cur_candidates)-1)]
                    candidate[i].remove(shuffle_note)
                    if shuffle_note.pitch not in pitch_group:
                        if len(current_group) >= 2:
                            test_group = pitch_group + [shuffle_note.pitch]
                            if not check_handshape(test_group,righthand):
                                continue
                        pitch_group.append(shuffle_note.pitch)
                        current_group.append(shuffle_note)
                        notes_group.remove(shuffle_note)

        for i in range(len(candidate)): 
            while valid_to_add(candidate[i],current_group):
                cur_candidates = candidate[i]
                shuffle_note = cur_candidates[random.randint(0, len(cur_candidates)-1)]
                candidate[i].remove(shuffle_note)
                if shuffle_note.pitch not in pitch_group:
                    if len(current_group) >= 2:
                        test_group = pitch_group + [shuffle_note.pitch]
                        if not check_handshape(test_group,righthand):
                            continue
                    pitch_group.append(shuffle_note.pitch)
                    current_group.append(shuffle_note)
                    notes_group.remove(shuffle_note)


        if not righthand:
            high = max([n.pitch for n in current_group])

        allocate_result.append(current_group)

        righthand = not righthand
        group += 1 #finish allocate notes to one group, update
    
    counter = 0
    while counter < len(notes_group):
        note = notes_group[counter]
        for i, allocated_group in enumerate(allocate_result):
            if len(allocated_group) >= 4:
                continue
            if len(allocated_group) < 4:
                pitch_group = [n.pitch for n in allocated_group]
                high = max([n.pitch for n in allocate_result[i-1]]) if i % 2 == 0 else 0
                righthand = True if i % 2 == 0 else False
                if valid_note_to_allocate(note,righthand,pitch_group,high):
                    allocated_group.append(note)
                    notes_group.remove(note)
                    break
        counter += 1

    if notes_group != []:
        print('Failed :(    ',len(notes_group), 'notes unallocated.')
        return False
    else:
        print('Success!')
        return allocate_result

# %%
word_groups = separate_word(new_notes,word_gap)
for item in word_groups:
    print(len(item))
# Out:
# 323
# 191
# 64
# 132
# 144

# %%
pprint(word_groups[0])

# %%
pianists = init_pianists()
current_allocate_group = copy.deepcopy(word_groups[0])

result = allocation_all(current_allocate_group, pianists)
for pianist in pianists:
    pianist.printnotes()
# Out:
# Pianist No. 1
# left ending time = 0 right ending time = 0
# Pianist No. 2
# left ending time = 0 right ending time = 0
# Pianist No. 3
# left ending time = 0 right ending time = 0
# Pianist No. 4
# left ending time = 0 right ending time = 0
# Pianist No. 5
# left ending time = 0 right ending time = 0
# Pianist No. 6
# left ending time = 0 right ending time = 0
# Pianist No. 7
# left ending time = 0 right ending time = 0
# Pianist No. 8
# left ending time = 0 right ending time = 0
# Pianist No. 9
# left ending time = 0 right ending time = 0
# Pianist No. 10
# left ending time = 0 right ending time = 0
# Pianist No. 11
# left ending time = 0 right ending time = 0
# Pianist No. 12
# left ending time = 0 right ending time = 0
# Pianist No. 13
# left ending time = 0 right ending time = 0
# Pianist No. 14
# left ending time = 0 right ending time = 0
# Pianist No. 15
# left ending time = 0 right ending time = 0
# Pianist No. 16
# left ending time = 0 right ending time = 0
# Pianist No. 17
# left ending time = 0 right ending time = 0
# Pianist No. 18
# left ending time = 0 right ending time = 0
# Pianist No. 19
# left ending time = 0 right ending time = 0
# Pianist No. 20
# left ending time = 0 right ending time = 0
# Pianist No. 21
# left ending time = 0 right ending time = 0
# Pianist No. 21
# left ending time = 40 right ending time = 35
# C:\Users\96326\AppData\Local\Temp\ipykernel_23012\3406167356.py:10: RuntimeWarning: overflow encountered in ubyte_scalars
#   if (note.pitch not in pitch_group) and (note.pitch-low <= 12):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\96326\Desktop\IIBproject\IIB_Project\notes_allocation_2.ipynb Cell 21 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> pianists = init_pianists()
#       <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> current_allocate_group = copy.deepcopy(word_groups[0])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> result = allocation_all(current_allocate_group, pianists)
#       <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=4'>5</a> for pianist in pianists:
#       <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a>     pianist.printnotes()
#
# c:\Users\96326\Desktop\IIBproject\IIB_Project\notes_allocation_2.ipynb Cell 21 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=11'>12</a> #allocate right hand
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=12'>13</a> righthand = not righthand
# ---> <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=13'>14</a> notes_group = allocation(cur_pianist, righthand, notes_group)
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=15'>16</a> if len(notes_group) == len(previous):
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=16'>17</a>     break
#
# c:\Users\96326\Desktop\IIBproject\IIB_Project\notes_allocation_2.ipynb Cell 21 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=7'>8</a>     endtime = cur_pianist.rendtime
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=9'>10</a> start_time = endtime + min_frame_gap
# ---> <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=11'>12</a> valid_notes_group = [note for note in notes_group if note.start >= start_time]
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=12'>13</a> if valid_notes_group == []:
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=13'>14</a>     return notes_group, 0
#
# c:\Users\96326\Desktop\IIBproject\IIB_Project\notes_allocation_2.ipynb Cell 21 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=7'>8</a>     endtime = cur_pianist.rendtime
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=9'>10</a> start_time = endtime + min_frame_gap
# ---> <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=11'>12</a> valid_notes_group = [note for note in notes_group if note.start >= start_time]
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=12'>13</a> if valid_notes_group == []:
#      <a href='vscode-notebook-cell:/c%3A/Users/96326/Desktop/IIBproject/IIB_Project/notes_allocation_2.ipynb#X43sZmlsZQ%3D%3D?line=13'>14</a>     return notes_group, 0
#
# AttributeError: 'list' object has no attribute 'start'

# %%
pianists = init_pianists()
current_allocate_group = copy.deepcopy(word_groups[0])
result = False
while not result:
    pianists = init_pianists()
    result = allocation_all(current_allocate_group, pianists)
    current_allocate_group = copy.deepcopy(word_groups[0])
    random.shuffle(current_allocate_group)

# %%
result_all = []
for i in range(2,5):
    print(i)
    current_allocate_group = copy.deepcopy(word_groups[i])
    #random.shuffle(current_allocate_group)
    result = False
    while not result:
        result = allocation_all(current_allocate_group)
        current_allocate_group = copy.deepcopy(word_groups[i])
        random.shuffle(current_allocate_group)
    result_all.append(result)

# %%
print(result_all)

# %%
current_allocate_group = copy.deepcopy(word_groups[4])
result = False
while not result:
    result = allocation(current_allocate_group)
    current_allocate_group = copy.deepcopy(word_groups[4])
    random.shuffle(current_allocate_group)

# %%
plot_notes(new_notes)
plt.show()
word_groups = separate_word(new_notes)
for g in word_groups:
    plot_notes(g)
plt.show()

# %%
mf = MIDIFile(2)     # track number
time = 0    # start at the beginning
mf.addTrackName(0, time, "Right")
mf.addTrackName(1, time, "Left")
mf.addTempo(0, time, 1200)
mf.addTempo(1, time, 1200)

# %%
for i in range(2):    
    for note in final_allocation2[1-i]:
        # v = int(50+note.sign()*12.5)
        v = int(20+note.sign()*20)
        mf.addNote(i,i,note.pitch+20, note.start, note.end-note.start+1,v)

# %%
with open("midifile/23Feb_allocation2.mid", 'wb') as outf:
   mf.writeFile(outf)

# %%
import numpy as np
array = np.array(result_all,dtype=object)
np.save("allocation_result_1Mar.npy", array)
